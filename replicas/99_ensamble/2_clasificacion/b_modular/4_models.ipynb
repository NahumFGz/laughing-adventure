# %%
import numpy as np
import pandas as pd
from utils.categorical_encoders import CategoricalEncoders

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score

import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
# 1. Leer el dataset
DATASET_PATH = 'data/dataset.csv'
dataset = pd.read_csv(DATASET_PATH, encoding='latin-1' ,sep=';')

# %%
# 2. Obtener las columnas binarias y categóricas
categorical = CategoricalEncoders(dataset=dataset)
binary_columns, categorical_columns = categorical.get_binary_categorical_columns()

# 3. Obtener los datos codificados
def get_list_data_encoded():
    encoded_methods = ['LabelEncoder', 'OneHotEncoder', 'OrdinalEncoder', 'FrequencyEncoder', 'BinaryEncoder', 'BackwardDifferenceEncoder']

    list_data_encoded = []
    for encoded_method in encoded_methods:
        data_encoded = categorical.provider(binary_columns, categorical_columns, method=encoded_method)
        list_data_encoded.append((encoded_method, data_encoded))
        print(f'Encoded method: {encoded_method} - Data shape: {data_encoded.shape}')

    return list_data_encoded

list_data_encoded = get_list_data_encoded()
# Out:
# Encoded method: LabelEncoder - Data shape: (8500, 12)
# Encoded method: OneHotEncoder - Data shape: (8500, 32)
# Encoded method: OrdinalEncoder - Data shape: (8500, 12)
# Encoded method: FrequencyEncoder - Data shape: (8500, 12)
# Encoded method: BinaryEncoder - Data shape: (8500, 25)
# Encoded method: BackwardDifferenceEncoder - Data shape: (8500, 33)

# %%
# 4. Generar los conjuntos de entrenamiento y prueba
def get_list_split_data(list_data_encoded):
    list_split_data = []
    for encoded_method, data_encoded in list_data_encoded:
        X = data_encoded.drop(columns=['Target'])
        y = data_encoded['Target']
        
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42, stratify=y)
        list_split_data.append((encoded_method, X_train, X_test, y_train, y_test))
        print(f'Encoded Method: {encoded_method}')

    return list_split_data

list_split_data = get_list_split_data(list_data_encoded)
# Out:
# Encoded Method: LabelEncoder
# Encoded Method: OneHotEncoder
# Encoded Method: OrdinalEncoder
# Encoded Method: FrequencyEncoder
# Encoded Method: BinaryEncoder
# Encoded Method: BackwardDifferenceEncoder

# %%
# Importar la clase BaseModels
from utils.base_models import BaseModels

# Inicializar BaseModels y definir los nombres de los modelos
base_models = BaseModels()
name_models = ['logistic_regression', 'decision_tree', 'random_forest',
               'gradient_boosting', 'svm', 'knn', 'naive_bayes', 'mlp',
               'lgbm', 'catboost', 'xgboost']

# Variable para almacenar los resultados
all_results = []

# Iterar sobre los conjuntos de datos codificados
for encoded_method, X_train, X_test, y_train, y_test in list_split_data:
    results = []
    for name in name_models:
        model = base_models.provider(name)
        model.fit(X_train, y_train)
        
        predict_train = model.predict_proba(X_train)[:, 1]
        predict_test = model.predict_proba(X_test)[:, 1]

        train_auc = roc_auc_score(y_train, predict_train)
        test_auc = roc_auc_score(y_test, predict_test)

        results.append((name, train_auc, test_auc))

        print(f"Encoded Method: {encoded_method} - AUC on training data with {name}: {train_auc:.3f}")
        print(f"AUC on testing data with {name}: {test_auc:.3f}")

    # Ordenar los resultados por test_auc de mayor a menor
    results.sort(key=lambda x: x[2], reverse=True)

    # Desempaquetar los resultados ordenados y almacenar con el método de codificación
    sorted_names, train_aucs, test_aucs = zip(*results)
    all_results.append((encoded_method, sorted_names, train_aucs, test_aucs))
# Out:
# Encoded Method: LabelEncoder - AUC on training data with logistic_regression: 0.726
# AUC on testing data with logistic_regression: 0.711
# Encoded Method: LabelEncoder - AUC on training data with decision_tree: 0.988
# AUC on testing data with decision_tree: 0.559
# Encoded Method: LabelEncoder - AUC on training data with random_forest: 0.984
# AUC on testing data with random_forest: 0.686
# Encoded Method: LabelEncoder - AUC on training data with gradient_boosting: 0.832
# AUC on testing data with gradient_boosting: 0.801
# Encoded Method: LabelEncoder - AUC on training data with svm: 0.812
# AUC on testing data with svm: 0.592
# Encoded Method: LabelEncoder - AUC on training data with knn: 0.904
# AUC on testing data with knn: 0.609
# Encoded Method: LabelEncoder - AUC on training data with naive_bayes: 0.709
# AUC on testing data with naive_bayes: 0.697
# Encoded Method: LabelEncoder - AUC on training data with mlp: 0.836
# AUC on testing data with mlp: 0.748
# [LightGBM] [Info] Number of positive: 272, number of negative: 6103
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001020 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 39
# [LightGBM] [Info] Number of data points in the train set: 6375, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.042667 -> initscore=-3.110734
# [LightGBM] [Info] Start training from score -3.110734
# Encoded Method: LabelEncoder - AUC on training data with lgbm: 0.953
# AUC on testing data with lgbm: 0.760
# Encoded Method: LabelEncoder - AUC on training data with catboost: 0.915
# AUC on testing data with catboost: 0.766
# Encoded Method: LabelEncoder - AUC on training data with xgboost: 0.964
# AUC on testing data with xgboost: 0.724
# Encoded Method: OneHotEncoder - AUC on training data with logistic_regression: 0.807
# AUC on testing data with logistic_regression: 0.812
# Encoded Method: OneHotEncoder - AUC on training data with decision_tree: 0.988
# AUC on testing data with decision_tree: 0.541
# Encoded Method: OneHotEncoder - AUC on training data with random_forest: 0.984
# AUC on testing data with random_forest: 0.679
# Encoded Method: OneHotEncoder - AUC on training data with gradient_boosting: 0.835
# AUC on testing data with gradient_boosting: 0.798
# Encoded Method: OneHotEncoder - AUC on training data with svm: 0.926
# AUC on testing data with svm: 0.642
# Encoded Method: OneHotEncoder - AUC on training data with knn: 0.905
# AUC on testing data with knn: 0.607
# Encoded Method: OneHotEncoder - AUC on training data with naive_bayes: 0.778
# AUC on testing data with naive_bayes: 0.777
# Encoded Method: OneHotEncoder - AUC on training data with mlp: 0.945
# AUC on testing data with mlp: 0.723
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 272, number of negative: 6103
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005916 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 58
# [LightGBM] [Info] Number of data points in the train set: 6375, number of used features: 29
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.042667 -> initscore=-3.110734
# [LightGBM] [Info] Start training from score -3.110734
# Encoded Method: OneHotEncoder - AUC on training data with lgbm: 0.948
# AUC on testing data with lgbm: 0.750
# Encoded Method: OneHotEncoder - AUC on training data with catboost: 0.932
# AUC on testing data with catboost: 0.756
# Encoded Method: OneHotEncoder - AUC on training data with xgboost: 0.955
# AUC on testing data with xgboost: 0.748
# Encoded Method: OrdinalEncoder - AUC on training data with logistic_regression: 0.701
# AUC on testing data with logistic_regression: 0.683
# Encoded Method: OrdinalEncoder - AUC on training data with decision_tree: 0.988
# AUC on testing data with decision_tree: 0.570
# Encoded Method: OrdinalEncoder - AUC on training data with random_forest: 0.983
# AUC on testing data with random_forest: 0.685
# Encoded Method: OrdinalEncoder - AUC on training data with gradient_boosting: 0.838
# AUC on testing data with gradient_boosting: 0.799
# Encoded Method: OrdinalEncoder - AUC on training data with svm: 0.842
# AUC on testing data with svm: 0.629
# Encoded Method: OrdinalEncoder - AUC on training data with knn: 0.904
# AUC on testing data with knn: 0.634
# Encoded Method: OrdinalEncoder - AUC on training data with naive_bayes: 0.700
# AUC on testing data with naive_bayes: 0.704
# Encoded Method: OrdinalEncoder - AUC on training data with mlp: 0.829
# AUC on testing data with mlp: 0.769
# [LightGBM] [Info] Number of positive: 272, number of negative: 6103
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001993 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 46
# [LightGBM] [Info] Number of data points in the train set: 6375, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.042667 -> initscore=-3.110734
# [LightGBM] [Info] Start training from score -3.110734
# Encoded Method: OrdinalEncoder - AUC on training data with lgbm: 0.948
# AUC on testing data with lgbm: 0.755
# Encoded Method: OrdinalEncoder - AUC on training data with catboost: 0.920
# AUC on testing data with catboost: 0.772
# Encoded Method: OrdinalEncoder - AUC on training data with xgboost: 0.959
# AUC on testing data with xgboost: 0.743
# Encoded Method: FrequencyEncoder - AUC on training data with logistic_regression: 0.744
# AUC on testing data with logistic_regression: 0.745
# Encoded Method: FrequencyEncoder - AUC on training data with decision_tree: 0.988
# AUC on testing data with decision_tree: 0.567
# Encoded Method: FrequencyEncoder - AUC on training data with random_forest: 0.984
# AUC on testing data with random_forest: 0.691
# Encoded Method: FrequencyEncoder - AUC on training data with gradient_boosting: 0.837
# AUC on testing data with gradient_boosting: 0.809
# Encoded Method: FrequencyEncoder - AUC on training data with svm: 0.637
# AUC on testing data with svm: 0.563
# Encoded Method: FrequencyEncoder - AUC on training data with knn: 0.906
# AUC on testing data with knn: 0.602
# Encoded Method: FrequencyEncoder - AUC on training data with naive_bayes: 0.731
# AUC on testing data with naive_bayes: 0.735
# Encoded Method: FrequencyEncoder - AUC on training data with mlp: 0.755
# AUC on testing data with mlp: 0.752
# [LightGBM] [Info] Number of positive: 272, number of negative: 6103
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000951 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 46
# [LightGBM] [Info] Number of data points in the train set: 6375, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.042667 -> initscore=-3.110734
# [LightGBM] [Info] Start training from score -3.110734
# Encoded Method: FrequencyEncoder - AUC on training data with lgbm: 0.944
# AUC on testing data with lgbm: 0.767
# Encoded Method: FrequencyEncoder - AUC on training data with catboost: 0.916
# AUC on testing data with catboost: 0.761
# Encoded Method: FrequencyEncoder - AUC on training data with xgboost: 0.954
# AUC on testing data with xgboost: 0.728
# Encoded Method: BinaryEncoder - AUC on training data with logistic_regression: 0.786
# AUC on testing data with logistic_regression: 0.780
# Encoded Method: BinaryEncoder - AUC on training data with decision_tree: 0.988
# AUC on testing data with decision_tree: 0.559
# Encoded Method: BinaryEncoder - AUC on training data with random_forest: 0.984
# AUC on testing data with random_forest: 0.663
# Encoded Method: BinaryEncoder - AUC on training data with gradient_boosting: 0.830
# AUC on testing data with gradient_boosting: 0.789
# Encoded Method: BinaryEncoder - AUC on training data with svm: 0.921
# AUC on testing data with svm: 0.658
# Encoded Method: BinaryEncoder - AUC on training data with knn: 0.902
# AUC on testing data with knn: 0.630
# Encoded Method: BinaryEncoder - AUC on training data with naive_bayes: 0.741
# AUC on testing data with naive_bayes: 0.739
# Encoded Method: BinaryEncoder - AUC on training data with mlp: 0.912
# AUC on testing data with mlp: 0.778
# [LightGBM] [Info] Number of positive: 272, number of negative: 6103
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004720 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 44
# [LightGBM] [Info] Number of data points in the train set: 6375, number of used features: 22
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.042667 -> initscore=-3.110734
# [LightGBM] [Info] Start training from score -3.110734
# Encoded Method: BinaryEncoder - AUC on training data with lgbm: 0.952
# AUC on testing data with lgbm: 0.763
# Encoded Method: BinaryEncoder - AUC on training data with catboost: 0.932
# AUC on testing data with catboost: 0.747
# Encoded Method: BinaryEncoder - AUC on training data with xgboost: 0.965
# AUC on testing data with xgboost: 0.727
# Encoded Method: BackwardDifferenceEncoder - AUC on training data with logistic_regression: 0.806
# AUC on testing data with logistic_regression: 0.814
# Encoded Method: BackwardDifferenceEncoder - AUC on training data with decision_tree: 0.988
# AUC on testing data with decision_tree: 0.575
# Encoded Method: BackwardDifferenceEncoder - AUC on training data with random_forest: 0.984
# AUC on testing data with random_forest: 0.671
# Encoded Method: BackwardDifferenceEncoder - AUC on training data with gradient_boosting: 0.838
# AUC on testing data with gradient_boosting: 0.798
# Encoded Method: BackwardDifferenceEncoder - AUC on training data with svm: 0.914
# AUC on testing data with svm: 0.661
# Encoded Method: BackwardDifferenceEncoder - AUC on training data with knn: 0.907
# AUC on testing data with knn: 0.639
# Encoded Method: BackwardDifferenceEncoder - AUC on training data with naive_bayes: 0.732
# AUC on testing data with naive_bayes: 0.743
# Encoded Method: BackwardDifferenceEncoder - AUC on training data with mlp: 0.930
# AUC on testing data with mlp: 0.749
# [LightGBM] [Info] Number of positive: 272, number of negative: 6103
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001838 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 84
# [LightGBM] [Info] Number of data points in the train set: 6375, number of used features: 29
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.042667 -> initscore=-3.110734
# [LightGBM] [Info] Start training from score -3.110734
# Encoded Method: BackwardDifferenceEncoder - AUC on training data with lgbm: 0.949
# AUC on testing data with lgbm: 0.752
# Encoded Method: BackwardDifferenceEncoder - AUC on training data with catboost: 0.921
# AUC on testing data with catboost: 0.774
# Encoded Method: BackwardDifferenceEncoder - AUC on training data with xgboost: 0.959
# AUC on testing data with xgboost: 0.743

# %%
def plot_results(all_results):
    for encoded_method, sorted_names, train_aucs, test_aucs in all_results:
        # Ordenar los resultados por Testing AUC de menor a mayor
        sorted_indices = np.argsort(test_aucs)
        sorted_names = np.array(sorted_names)[sorted_indices]
        train_aucs = np.array(train_aucs)[sorted_indices]
        test_aucs = np.array(test_aucs)[sorted_indices]

        plt.figure(figsize=(14, 7))

        # Gráfico de líneas
        plt.plot(sorted_names, train_aucs, label='Training AUC', marker='o', color='skyblue')
        plt.plot(sorted_names, test_aucs, label='Testing AUC', marker='o', color='salmon')

        # Añadir los valores a los puntos
        for i, txt in enumerate(train_aucs):
            plt.annotate(f'{txt:.3f}', (sorted_names[i], train_aucs[i]), textcoords="offset points", xytext=(0,10), ha='center', color='blue')
        for i, txt in enumerate(test_aucs):
            plt.annotate(f'{txt:.3f}', (sorted_names[i], test_aucs[i]), textcoords="offset points", xytext=(0,-15), ha='center', color='red')

        plt.xlabel('Modelos')
        plt.ylabel('AUC')
        plt.title(f'AUC for Training and Testing - {encoded_method}')
        plt.xticks(rotation=45)
        plt.legend()
        plt.grid(True)
        plt.tight_layout()
        plt.show()

# Llamar a la función para generar los gráficos
plot_results(all_results)

# %%
# Consolidar todos los resultados en una lista
consolidated_results = []
for encoded_method, sorted_names, train_aucs, test_aucs in all_results:
    for name, train_auc, test_auc in zip(sorted_names, train_aucs, test_aucs):
        full_model_name = f"{encoded_method} - {name}"
        consolidated_results.append((full_model_name, train_auc, test_auc))

# Ordenar los resultados por test_auc de mayor a menor y seleccionar el top 10
consolidated_results.sort(key=lambda x: x[2], reverse=False)
top_10_results = consolidated_results[-10:]

# Desempaquetar los resultados del top 10
top_10_names, top_10_train_aucs, top_10_test_aucs = zip(*top_10_results)

plt.figure(figsize=(14, 7))

# Gráfico de líneas para el top 10
plt.plot(top_10_names, top_10_train_aucs, label='Training AUC', marker='o', color='skyblue')
plt.plot(top_10_names, top_10_test_aucs, label='Testing AUC', marker='o', color='salmon')

# Añadir los valores a los puntos
for i, txt in enumerate(top_10_train_aucs):
    plt.annotate(f'{txt:.3f}', (top_10_names[i], top_10_train_aucs[i]), textcoords="offset points", xytext=(0,10), ha='center', color='blue')
for i, txt in enumerate(top_10_test_aucs):
    plt.annotate(f'{txt:.3f}', (top_10_names[i], top_10_test_aucs[i]), textcoords="offset points", xytext=(0,-15), ha='center', color='red')

plt.xlabel('Modelos')
plt.ylabel('AUC')
plt.title('Top 10 Models by Testing AUC')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
