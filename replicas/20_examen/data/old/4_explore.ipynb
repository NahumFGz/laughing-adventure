# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_parquet('./data/data.parquet')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1305605 entries, 0 to 1305604
# Data columns (total 40 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   NUMPRIORIZACION       1305605 non-null  int64
#  1   NC_DISTR12            804672 non-null   float64
#  2   TOTGEST6              873288 non-null   float64
#  3   TOTGEST12             924166 non-null   float64
#  4   IDGRUPO               1305605 non-null  int64
#  5   DIAS_ACT              1305605 non-null  int64
#  6   FBK_ULT6              873288 non-null   object
#  7   FBK_ULT12             924166 non-null   object
#  8   FBK_BEST6             873288 non-null   object
#  9   DIAS_BEST6            873288 non-null   float64
#  10  DIAS_ULT6             873288 non-null   float64
#  11  FBK_BEST12            924166 non-null   object
#  12  DIAS_BEST12           924166 non-null   float64
#  13  DIAS_ULT12            924166 non-null   float64
#  14  CNE_CTD12             448690 non-null   float64
#  15  CNE_CTD6              381081 non-null   float64
#  16  CNE_DIAS6             381081 non-null   float64
#  17  CNE_DISTR6            381081 non-null   float64
#  18  CNE_DISTR12           448690 non-null   float64
#  19  CNE_DIAS12            448690 non-null   float64
#  20  NC_CTD12              804672 non-null   float64
#  21  NC_DIAS6              738828 non-null   float64
#  22  NC_DIAS12             804672 non-null   float64
#  23  NC_CTD6               738828 non-null   float64
#  24  RECENCIA_APP          115788 non-null   float64
#  25  COD_SALA              1305605 non-null  object
#  26  NT_CTD12              72399 non-null    float64
#  27  NT_DISTR12            72399 non-null    float64
#  28  NT_DIAS12             72399 non-null    float64
#  29  FEC_LLAMADA           1305605 non-null  object
#  30  NT_CTD6               47283 non-null    float64
#  31  NT_DISTR6             47283 non-null    float64
#  32  NT_DIAS6              47283 non-null    float64
#  33  PROVINCIA             1305605 non-null  object
#  34  DEPARTAMENTO          1305605 non-null  object
#  35  INGRESO_NETO_VIGENTE  1301894 non-null  float64
#  36  INGRESO_BRUTO         1301894 non-null  float64
#  37  SEGMENTO              1301841 non-null  object
#  38  RANGO_INGRESOS        1305604 non-null  object
#  39  TARGET                1305605 non-null  int64
# dtypes: float64(26), int64(4), object(10)
# memory usage: 398.4+ MB

# %%
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
fig, axs = plt.subplots(6, 5, figsize=(15, 20))
columns = df.select_dtypes(include=['int64', 'float64']).columns

for i, column in enumerate(columns):
    row = i // 5
    col = i % 5
    sns.histplot(df[column].dropna(), kde=True, ax=axs[row, col])
    axs[row, col].set_title('' + column)

plt.tight_layout()
plt.show()
