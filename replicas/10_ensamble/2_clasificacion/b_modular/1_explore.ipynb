# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
DATASET_PATH = 'data/DataBelcorp.csv'
dataset = pd.read_csv(DATASET_PATH, encoding='latin-1' ,sep=';')
dataset.head()
# Out:
#    Codigo     Reclutamiento        Ocupacion               Jefe_Hogar  \
# 0  A00001  Socia Empresaria       Negociante  Trabajo Oficina Parcial
# 1  A00002  Socia Empresaria  Tiempo Completo               Negociante
# 2  A00003  Socia Empresaria  Tiempo Completo               Negociante
# 3  A00004      Otros Medios      Ama de Casa    Construcción y Afines
# 4  A00005  Socia Empresaria      Ama de Casa          Trabajos Casual
#
#   Prioridad_Negocio_VD     Porque_VD Tiene_TC Tiene_Prestamo  \
# 0   No tiene Prioridad  Tiempo Libre       SI             SI
# 1   No tiene Prioridad    Incentivos       SI             SI
# 2   No tiene Prioridad      Ganancia       SI             SI
# 3   No tiene Prioridad  Tiempo Libre       NO             NO
# 4   No tiene Prioridad  Tiempo Libre       SI             SI
#
#   Venta_Competencia   email telefono_fijo telefono_movil  Target
# 0                SI  Valido        Valido         Valido       0
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8500 entries, 0 to 8499
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Codigo                8500 non-null   object
#  1   Reclutamiento         8500 non-null   object
#  2   Ocupacion             8500 non-null   object
#  3   Jefe_Hogar            8500 non-null   object
#  4   Prioridad_Negocio_VD  8500 non-null   object
#  5   Porque_VD             8500 non-null   object
#  6   Tiene_TC              8500 non-null   object
#  7   Tiene_Prestamo        8500 non-null   object
#  8   Venta_Competencia     8500 non-null   object
#  9   email                 8500 non-null   object
#  10  telefono_fijo         8500 non-null   object
#  11  telefono_movil        8500 non-null   object
#  12  Target                8500 non-null   int64
# dtypes: int64(1), object(12)
# memory usage: 863.4+ KB

# %%
dataset.Codigo.nunique()
# Out:
# 8500

# %%
sns.heatmap(dataset.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
# Eliminar columna codigo
dataset.drop('Codigo', axis=1, inplace=True)
dataset.to_csv('./data/dataset.csv', encoding='latin-1', sep=';', index=False, header=True)
dataset.head()
# Out:
#       Reclutamiento        Ocupacion               Jefe_Hogar  \
# 0  Socia Empresaria       Negociante  Trabajo Oficina Parcial
# 1  Socia Empresaria  Tiempo Completo               Negociante
# 2  Socia Empresaria  Tiempo Completo               Negociante
# 3      Otros Medios      Ama de Casa    Construcción y Afines
# 4  Socia Empresaria      Ama de Casa          Trabajos Casual
#
#   Prioridad_Negocio_VD     Porque_VD Tiene_TC Tiene_Prestamo  \
# 0   No tiene Prioridad  Tiempo Libre       SI             SI
# 1   No tiene Prioridad    Incentivos       SI             SI
# 2   No tiene Prioridad      Ganancia       SI             SI
# 3   No tiene Prioridad  Tiempo Libre       NO             NO
# 4   No tiene Prioridad  Tiempo Libre       SI             SI
#
#   Venta_Competencia   email telefono_fijo telefono_movil  Target
# 0                SI  Valido        Valido         Valido       0
# 1                SI  Valido        Valido         Valido       0
# ...
