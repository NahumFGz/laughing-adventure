# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split

from utils.balance_data import Undersampler
from utils.categorical_encoders import CategoricalEncoders

import warnings
warnings.filterwarnings('ignore')

# %%
# 1. Leer el dataset
DATASET_PATH = 'data/dataset.csv'
dataset = pd.read_csv(DATASET_PATH, encoding='latin-1' ,sep=';')

# %%
# 2. Obtener las columnas binarias y categóricas
categorical = CategoricalEncoders(dataset=dataset)
binary_columns, categorical_columns = categorical.get_binary_categorical_columns()

# 3. Obtener los datos codificados
def get_list_data_encoded():
    encoded_methods = ['LabelEncoder', 'OneHotEncoder', 'OrdinalEncoder', 'FrequencyEncoder', 'BinaryEncoder', 'BackwardDifferenceEncoder']

    i = 0
    list_data_encoded = []
    for encoded_method in encoded_methods:
        data_encoded = categorical.provider(binary_columns, categorical_columns, method=encoded_method)
        list_data_encoded.append((encoded_method, data_encoded))
        print(f'{str(i).zfill(2)}: Encoded method: {encoded_method} - Data shape: {data_encoded.shape}')
        i += 1

    return list_data_encoded

list_data_encoded = get_list_data_encoded()
# Out:
# 00: Encoded method: LabelEncoder - Data shape: (8500, 12)
# 01: Encoded method: OneHotEncoder - Data shape: (8500, 32)
# 02: Encoded method: OrdinalEncoder - Data shape: (8500, 12)
# 03: Encoded method: FrequencyEncoder - Data shape: (8500, 12)
# 04: Encoded method: BinaryEncoder - Data shape: (8500, 25)
# 05: Encoded method: BackwardDifferenceEncoder - Data shape: (8500, 33)

# %%
from sklearn.model_selection import train_test_split

def get_list_data_encoded_split(list_data_encoded, column_target_name, test_size=0.2, random_state=42):
    
    i=0
    list_data_split = []
    for method, data in list_data_encoded:
        X = data.drop(columns=[column_target_name])
        y = data[column_target_name]

        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
        list_data_split.append((method, X_train, X_test, y_train, y_test))

        print(f'{str(i).zfill(2)}: Method: {method} - Train shape: {X_train.shape}, Test shape: {X_test.shape}')
        i += 1

    
    return list_data_split

# Uso de la función
list_data_encoded_split = get_list_data_encoded_split(list_data_encoded, column_target_name='Target')

_, X_train, X_test, y_train, y_test = list_data_encoded_split[0]
print('\ny_train:', str(y_train.value_counts()))
print('\ny_test:', str(y_test.value_counts()))
# Out:
# 00: Method: LabelEncoder - Train shape: (6800, 11), Test shape: (1700, 11)
# 01: Method: OneHotEncoder - Train shape: (6800, 31), Test shape: (1700, 31)
# 02: Method: OrdinalEncoder - Train shape: (6800, 11), Test shape: (1700, 11)
# 03: Method: FrequencyEncoder - Train shape: (6800, 11), Test shape: (1700, 11)
# 04: Method: BinaryEncoder - Train shape: (6800, 24), Test shape: (1700, 24)
# 05: Method: BackwardDifferenceEncoder - Train shape: (6800, 32), Test shape: (1700, 32)
#
# y_train: Target
# 0    6500
# 1     300
# Name: count, dtype: int64
#
# y_test: Target
# 0    1637
# 1      63
# Name: count, dtype: int64

# %%
# 4. Aplicar balanceo de clases a cada list_data_encoded
undersampler = Undersampler()

def get_list_data_encoded_balanced(list_data_encoded_split):
    undersampler_methods = ['random', 'nearmiss', 'tomek', 'centroids', 'enn', 'allknn']
    
    i=0
    list_data_encoded_balanced = []
    for encoded_method, X_train, X_test, y_train, y_test in list_data_encoded_split:
        for undersampler_method in undersampler_methods:
            X_train_balanced, y_train_balanced = undersampler.provider(method=undersampler_method, X=X_train, y=y_train)
            
            list_data_encoded_balanced.append((encoded_method, 
                                               undersampler_method, 
                                               X_train_balanced, 
                                               X_test,
                                               y_train_balanced,
                                               y_test
                                               ))
            print(f'{str(i).zfill(2)}: Encoded method: {encoded_method} - Undersampler method: {undersampler_method} - Train shape: {X_train_balanced.shape} - Test shape: {X_test.shape}')
            i += 1

    return list_data_encoded_balanced

# Aplicar el balanceo a los datos de entrenamiento
list_data_encoded_split_balanced = get_list_data_encoded_balanced(list_data_encoded_split)

_, _, X_train, X_test, y_train, y_test = list_data_encoded_split_balanced[0]
print('\ny_train:', str(y_train.value_counts()))
print('\ny_test:', str(y_test.value_counts()))
# Out:
# 00: Encoded method: LabelEncoder - Undersampler method: random - Train shape: (600, 11) - Test shape: (1700, 11)
# 01: Encoded method: LabelEncoder - Undersampler method: nearmiss - Train shape: (600, 11) - Test shape: (1700, 11)
# 02: Encoded method: LabelEncoder - Undersampler method: tomek - Train shape: (6773, 11) - Test shape: (1700, 11)
# 03: Encoded method: LabelEncoder - Undersampler method: centroids - Train shape: (600, 11) - Test shape: (1700, 11)
# 04: Encoded method: LabelEncoder - Undersampler method: enn - Train shape: (6231, 11) - Test shape: (1700, 11)
# 05: Encoded method: LabelEncoder - Undersampler method: allknn - Train shape: (6403, 11) - Test shape: (1700, 11)
# 06: Encoded method: OneHotEncoder - Undersampler method: random - Train shape: (600, 31) - Test shape: (1700, 31)
# 07: Encoded method: OneHotEncoder - Undersampler method: nearmiss - Train shape: (600, 31) - Test shape: (1700, 31)
# 08: Encoded method: OneHotEncoder - Undersampler method: tomek - Train shape: (6778, 31) - Test shape: (1700, 31)
# 09: Encoded method: OneHotEncoder - Undersampler method: centroids - Train shape: (600, 31) - Test shape: (1700, 31)
# 10: Encoded method: OneHotEncoder - Undersampler method: enn - Train shape: (6184, 31) - Test shape: (1700, 31)
# 11: Encoded method: OneHotEncoder - Undersampler method: allknn - Train shape: (6463, 31) - Test shape: (1700, 31)
# 12: Encoded method: OrdinalEncoder - Undersampler method: random - Train shape: (600, 11) - Test shape: (1700, 11)
# 13: Encoded method: OrdinalEncoder - Undersampler method: nearmiss - Train shape: (600, 11) - Test shape: (1700, 11)
# 14: Encoded method: OrdinalEncoder - Undersampler method: tomek - Train shape: (6769, 11) - Test shape: (1700, 11)
# 15: Encoded method: OrdinalEncoder - Undersampler method: centroids - Train shape: (600, 11) - Test shape: (1700, 11)
# 16: Encoded method: OrdinalEncoder - Undersampler method: enn - Train shape: (6212, 11) - Test shape: (1700, 11)
# 17: Encoded method: OrdinalEncoder - Undersampler method: allknn - Train shape: (6394, 11) - Test shape: (1700, 11)
# 18: Encoded method: FrequencyEncoder - Undersampler method: random - Train shape: (600, 11) - Test shape: (1700, 11)
# 19: Encoded method: FrequencyEncoder - Undersampler method: nearmiss - Train shape: (600, 11) - Test shape: (1700, 11)
# 20: Encoded method: FrequencyEncoder - Undersampler method: tomek - Train shape: (6738, 11) - Test shape: (1700, 11)
# 21: Encoded method: FrequencyEncoder - Undersampler method: centroids - Train shape: (600, 11) - Test shape: (1700, 11)
# 22: Encoded method: FrequencyEncoder - Undersampler method: enn - Train shape: (6172, 11) - Test shape: (1700, 11)
# 23: Encoded method: FrequencyEncoder - Undersampler method: allknn - Train shape: (6233, 11) - Test shape: (1700, 11)
# 24: Encoded method: BinaryEncoder - Undersampler method: random - Train shape: (600, 24) - Test shape: (1700, 24)
# 25: Encoded method: BinaryEncoder - Undersampler method: nearmiss - Train shape: (600, 24) - Test shape: (1700, 24)
# 26: Encoded method: BinaryEncoder - Undersampler method: tomek - Train shape: (6784, 24) - Test shape: (1700, 24)
# 27: Encoded method: BinaryEncoder - Undersampler method: centroids - Train shape: (600, 24) - Test shape: (1700, 24)
# 28: Encoded method: BinaryEncoder - Undersampler method: enn - Train shape: (6161, 24) - Test shape: (1700, 24)
# 29: Encoded method: BinaryEncoder - Undersampler method: allknn - Train shape: (6081, 24) - Test shape: (1700, 24)
# 30: Encoded method: BackwardDifferenceEncoder - Undersampler method: random - Train shape: (600, 32) - Test shape: (1700, 32)
# 31: Encoded method: BackwardDifferenceEncoder - Undersampler method: nearmiss - Train shape: (600, 32) - Test shape: (1700, 32)
# 32: Encoded method: BackwardDifferenceEncoder - Undersampler method: tomek - Train shape: (6769, 32) - Test shape: (1700, 32)
# 33: Encoded method: BackwardDifferenceEncoder - Undersampler method: centroids - Train shape: (600, 32) - Test shape: (1700, 32)
# 34: Encoded method: BackwardDifferenceEncoder - Undersampler method: enn - Train shape: (6213, 32) - Test shape: (1700, 32)
# 35: Encoded method: BackwardDifferenceEncoder - Undersampler method: allknn - Train shape: (6374, 32) - Test shape: (1700, 32)
#
# y_train: Target
# 0    300
# 1    300
# Name: count, dtype: int64
#
# y_test: Target
# 0    1637
# 1      63
# Name: count, dtype: int64

# %%
from sklearn.metrics import roc_auc_score
from utils.base_models import BaseModels

# Inicializar BaseModels y definir los nombres de los modelos
base_models = BaseModels()
name_models = ['logistic_regression', 'decision_tree', 'random_forest',
               'gradient_boosting', 'svm', 'knn', 'naive_bayes', 'mlp',
               'lgbm', 'catboost', 'xgboost']

i = 0
all_results = []
for encoded_method, oversampler_method, X_train, X_test, y_train, y_test in list_data_encoded_split_balanced:
    results = []
    for name in name_models:
        model = base_models.provider(name)
        model.fit(X_train, y_train)
        
        predict_train = model.predict_proba(X_train)[:, 1]
        predict_test = model.predict_proba(X_test)[:, 1]

        train_auc = roc_auc_score(y_train, predict_train)
        test_auc = roc_auc_score(y_test, predict_test)

        results.append((name, train_auc, test_auc))

        print(f"{str(i).zfill(2)}: Encoded Method: {encoded_method} - Oversampler Method: {oversampler_method} - AUC on training data with {name}: {train_auc:.3f}")
        print(f"AUC on testing data with {name}: {test_auc:.3f}")
        i += 1

    # Ordenar los resultados por test_auc de mayor a menor
    results.sort(key=lambda x: x[2], reverse=True)

    # Desempaquetar los resultados ordenados y almacenar con el método de codificación y balanceo
    sorted_names, train_aucs, test_aucs = zip(*results)
    all_results.append((encoded_method, oversampler_method, sorted_names, train_aucs, test_aucs))
# Out:
# 00: Encoded Method: LabelEncoder - Oversampler Method: random - AUC on training data with logistic_regression: 0.709
# AUC on testing data with logistic_regression: 0.676
# 01: Encoded Method: LabelEncoder - Oversampler Method: random - AUC on training data with decision_tree: 0.995
# AUC on testing data with decision_tree: 0.597
# 02: Encoded Method: LabelEncoder - Oversampler Method: random - AUC on training data with random_forest: 0.994
# AUC on testing data with random_forest: 0.680
# 03: Encoded Method: LabelEncoder - Oversampler Method: random - AUC on training data with gradient_boosting: 0.886
# AUC on testing data with gradient_boosting: 0.733
# 04: Encoded Method: LabelEncoder - Oversampler Method: random - AUC on training data with svm: 0.740
# AUC on testing data with svm: 0.701
# 05: Encoded Method: LabelEncoder - Oversampler Method: random - AUC on training data with knn: 0.809
# AUC on testing data with knn: 0.637
# 06: Encoded Method: LabelEncoder - Oversampler Method: random - AUC on training data with naive_bayes: 0.698
# AUC on testing data with naive_bayes: 0.660
# 07: Encoded Method: LabelEncoder - Oversampler Method: random - AUC on training data with mlp: 0.811
# AUC on testing data with mlp: 0.696
# [LightGBM] [Info] Number of positive: 300, number of negative: 300
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001055 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 39
# [LightGBM] [Info] Number of data points in the train set: 600, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 08: Encoded Method: LabelEncoder - Oversampler Method: random - AUC on training data with lgbm: 0.939
# AUC on testing data with lgbm: 0.716
# 09: Encoded Method: LabelEncoder - Oversampler Method: random - AUC on training data with catboost: 0.950
# AUC on testing data with catboost: 0.725
# 10: Encoded Method: LabelEncoder - Oversampler Method: random - AUC on training data with xgboost: 0.989
# AUC on testing data with xgboost: 0.696
# 11: Encoded Method: LabelEncoder - Oversampler Method: nearmiss - AUC on training data with logistic_regression: 0.889
# AUC on testing data with logistic_regression: 0.543
# 12: Encoded Method: LabelEncoder - Oversampler Method: nearmiss - AUC on training data with decision_tree: 0.952
# AUC on testing data with decision_tree: 0.505
# 13: Encoded Method: LabelEncoder - Oversampler Method: nearmiss - AUC on training data with random_forest: 0.952
# AUC on testing data with random_forest: 0.566
# 14: Encoded Method: LabelEncoder - Oversampler Method: nearmiss - AUC on training data with gradient_boosting: 0.948
# AUC on testing data with gradient_boosting: 0.536
# 15: Encoded Method: LabelEncoder - Oversampler Method: nearmiss - AUC on training data with svm: 0.913
# AUC on testing data with svm: 0.542
# 16: Encoded Method: LabelEncoder - Oversampler Method: nearmiss - AUC on training data with knn: 0.917
# AUC on testing data with knn: 0.540
# 17: Encoded Method: LabelEncoder - Oversampler Method: nearmiss - AUC on training data with naive_bayes: 0.876
# AUC on testing data with naive_bayes: 0.485
# 18: Encoded Method: LabelEncoder - Oversampler Method: nearmiss - AUC on training data with mlp: 0.919
# AUC on testing data with mlp: 0.527
# [LightGBM] [Info] Number of positive: 300, number of negative: 300
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006153 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 36
# [LightGBM] [Info] Number of data points in the train set: 600, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 19: Encoded Method: LabelEncoder - Oversampler Method: nearmiss - AUC on training data with lgbm: 0.949
# AUC on testing data with lgbm: 0.555
# 20: Encoded Method: LabelEncoder - Oversampler Method: nearmiss - AUC on training data with catboost: 0.950
# AUC on testing data with catboost: 0.536
# 21: Encoded Method: LabelEncoder - Oversampler Method: nearmiss - AUC on training data with xgboost: 0.952
# AUC on testing data with xgboost: 0.541
# 22: Encoded Method: LabelEncoder - Oversampler Method: tomek - AUC on training data with logistic_regression: 0.727
# AUC on testing data with logistic_regression: 0.673
# 23: Encoded Method: LabelEncoder - Oversampler Method: tomek - AUC on training data with decision_tree: 0.988
# AUC on testing data with decision_tree: 0.547
# 24: Encoded Method: LabelEncoder - Oversampler Method: tomek - AUC on training data with random_forest: 0.984
# AUC on testing data with random_forest: 0.680
# 25: Encoded Method: LabelEncoder - Oversampler Method: tomek - AUC on training data with gradient_boosting: 0.839
# AUC on testing data with gradient_boosting: 0.773
# 26: Encoded Method: LabelEncoder - Oversampler Method: tomek - AUC on training data with svm: 0.806
# AUC on testing data with svm: 0.535
# 27: Encoded Method: LabelEncoder - Oversampler Method: tomek - AUC on training data with knn: 0.905
# AUC on testing data with knn: 0.572
# 28: Encoded Method: LabelEncoder - Oversampler Method: tomek - AUC on training data with naive_bayes: 0.716
# AUC on testing data with naive_bayes: 0.662
# 29: Encoded Method: LabelEncoder - Oversampler Method: tomek - AUC on training data with mlp: 0.849
# AUC on testing data with mlp: 0.697
# [LightGBM] [Info] Number of positive: 300, number of negative: 6473
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001295 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 39
# [LightGBM] [Info] Number of data points in the train set: 6773, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.044294 -> initscore=-3.071612
# [LightGBM] [Info] Start training from score -3.071612
# 30: Encoded Method: LabelEncoder - Oversampler Method: tomek - AUC on training data with lgbm: 0.954
# AUC on testing data with lgbm: 0.706
# 31: Encoded Method: LabelEncoder - Oversampler Method: tomek - AUC on training data with catboost: 0.930
# AUC on testing data with catboost: 0.707
# 32: Encoded Method: LabelEncoder - Oversampler Method: tomek - AUC on training data with xgboost: 0.966
# AUC on testing data with xgboost: 0.685
# 33: Encoded Method: LabelEncoder - Oversampler Method: centroids - AUC on training data with logistic_regression: 0.937
# AUC on testing data with logistic_regression: 0.538
# 34: Encoded Method: LabelEncoder - Oversampler Method: centroids - AUC on training data with decision_tree: 1.000
# AUC on testing data with decision_tree: 0.568
# 35: Encoded Method: LabelEncoder - Oversampler Method: centroids - AUC on training data with random_forest: 1.000
# AUC on testing data with random_forest: 0.565
# 36: Encoded Method: LabelEncoder - Oversampler Method: centroids - AUC on training data with gradient_boosting: 0.994
# AUC on testing data with gradient_boosting: 0.616
# 37: Encoded Method: LabelEncoder - Oversampler Method: centroids - AUC on training data with svm: 0.959
# AUC on testing data with svm: 0.581
# 38: Encoded Method: LabelEncoder - Oversampler Method: centroids - AUC on training data with knn: 0.954
# AUC on testing data with knn: 0.534
# 39: Encoded Method: LabelEncoder - Oversampler Method: centroids - AUC on training data with naive_bayes: 0.934
# AUC on testing data with naive_bayes: 0.530
# 40: Encoded Method: LabelEncoder - Oversampler Method: centroids - AUC on training data with mlp: 0.969
# AUC on testing data with mlp: 0.597
# [LightGBM] [Info] Number of positive: 300, number of negative: 300
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000654 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 39
# [LightGBM] [Info] Number of data points in the train set: 600, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 41: Encoded Method: LabelEncoder - Oversampler Method: centroids - AUC on training data with lgbm: 1.000
# AUC on testing data with lgbm: 0.602
# 42: Encoded Method: LabelEncoder - Oversampler Method: centroids - AUC on training data with catboost: 1.000
# AUC on testing data with catboost: 0.595
# 43: Encoded Method: LabelEncoder - Oversampler Method: centroids - AUC on training data with xgboost: 1.000
# AUC on testing data with xgboost: 0.598
# 44: Encoded Method: LabelEncoder - Oversampler Method: enn - AUC on training data with logistic_regression: 0.742
# AUC on testing data with logistic_regression: 0.671
# 45: Encoded Method: LabelEncoder - Oversampler Method: enn - AUC on training data with decision_tree: 0.996
# AUC on testing data with decision_tree: 0.536
# 46: Encoded Method: LabelEncoder - Oversampler Method: enn - AUC on training data with random_forest: 0.993
# AUC on testing data with random_forest: 0.662
# 47: Encoded Method: LabelEncoder - Oversampler Method: enn - AUC on training data with gradient_boosting: 0.854
# AUC on testing data with gradient_boosting: 0.756
# 48: Encoded Method: LabelEncoder - Oversampler Method: enn - AUC on training data with svm: 0.804
# AUC on testing data with svm: 0.552
# 49: Encoded Method: LabelEncoder - Oversampler Method: enn - AUC on training data with knn: 0.933
# AUC on testing data with knn: 0.566
# 50: Encoded Method: LabelEncoder - Oversampler Method: enn - AUC on training data with naive_bayes: 0.729
# AUC on testing data with naive_bayes: 0.660
# 51: Encoded Method: LabelEncoder - Oversampler Method: enn - AUC on training data with mlp: 0.865
# AUC on testing data with mlp: 0.706
# [LightGBM] [Info] Number of positive: 300, number of negative: 5931
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001486 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 39
# [LightGBM] [Info] Number of data points in the train set: 6231, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.048146 -> initscore=-2.984166
# [LightGBM] [Info] Start training from score -2.984166
# 52: Encoded Method: LabelEncoder - Oversampler Method: enn - AUC on training data with lgbm: 0.970
# AUC on testing data with lgbm: 0.710
# 53: Encoded Method: LabelEncoder - Oversampler Method: enn - AUC on training data with catboost: 0.953
# AUC on testing data with catboost: 0.711
# 54: Encoded Method: LabelEncoder - Oversampler Method: enn - AUC on training data with xgboost: 0.978
# AUC on testing data with xgboost: 0.679
# 55: Encoded Method: LabelEncoder - Oversampler Method: allknn - AUC on training data with logistic_regression: 0.740
# AUC on testing data with logistic_regression: 0.672
# 56: Encoded Method: LabelEncoder - Oversampler Method: allknn - AUC on training data with decision_tree: 0.995
# AUC on testing data with decision_tree: 0.539
# 57: Encoded Method: LabelEncoder - Oversampler Method: allknn - AUC on training data with random_forest: 0.991
# AUC on testing data with random_forest: 0.672
# 58: Encoded Method: LabelEncoder - Oversampler Method: allknn - AUC on training data with gradient_boosting: 0.854
# AUC on testing data with gradient_boosting: 0.765
# 59: Encoded Method: LabelEncoder - Oversampler Method: allknn - AUC on training data with svm: 0.794
# AUC on testing data with svm: 0.550
# 60: Encoded Method: LabelEncoder - Oversampler Method: allknn - AUC on training data with knn: 0.913
# AUC on testing data with knn: 0.566
# 61: Encoded Method: LabelEncoder - Oversampler Method: allknn - AUC on training data with naive_bayes: 0.727
# AUC on testing data with naive_bayes: 0.662
# 62: Encoded Method: LabelEncoder - Oversampler Method: allknn - AUC on training data with mlp: 0.849
# AUC on testing data with mlp: 0.717
# [LightGBM] [Info] Number of positive: 300, number of negative: 6103
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000975 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 39
# [LightGBM] [Info] Number of data points in the train set: 6403, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.046853 -> initscore=-3.012753
# [LightGBM] [Info] Start training from score -3.012753
# 63: Encoded Method: LabelEncoder - Oversampler Method: allknn - AUC on training data with lgbm: 0.966
# AUC on testing data with lgbm: 0.723
# 64: Encoded Method: LabelEncoder - Oversampler Method: allknn - AUC on training data with catboost: 0.946
# AUC on testing data with catboost: 0.719
# 65: Encoded Method: LabelEncoder - Oversampler Method: allknn - AUC on training data with xgboost: 0.975
# AUC on testing data with xgboost: 0.690
# 66: Encoded Method: OneHotEncoder - Oversampler Method: random - AUC on training data with logistic_regression: 0.819
# AUC on testing data with logistic_regression: 0.767
# 67: Encoded Method: OneHotEncoder - Oversampler Method: random - AUC on training data with decision_tree: 0.995
# AUC on testing data with decision_tree: 0.634
# 68: Encoded Method: OneHotEncoder - Oversampler Method: random - AUC on training data with random_forest: 0.994
# AUC on testing data with random_forest: 0.714
# 69: Encoded Method: OneHotEncoder - Oversampler Method: random - AUC on training data with gradient_boosting: 0.879
# AUC on testing data with gradient_boosting: 0.754
# 70: Encoded Method: OneHotEncoder - Oversampler Method: random - AUC on training data with svm: 0.866
# AUC on testing data with svm: 0.747
# 71: Encoded Method: OneHotEncoder - Oversampler Method: random - AUC on training data with knn: 0.840
# AUC on testing data with knn: 0.662
# 72: Encoded Method: OneHotEncoder - Oversampler Method: random - AUC on training data with naive_bayes: 0.803
# AUC on testing data with naive_bayes: 0.753
# 73: Encoded Method: OneHotEncoder - Oversampler Method: random - AUC on training data with mlp: 0.938
# AUC on testing data with mlp: 0.760
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 300, number of negative: 300
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001562 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 50
# [LightGBM] [Info] Number of data points in the train set: 600, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 74: Encoded Method: OneHotEncoder - Oversampler Method: random - AUC on training data with lgbm: 0.921
# AUC on testing data with lgbm: 0.712
# 75: Encoded Method: OneHotEncoder - Oversampler Method: random - AUC on training data with catboost: 0.941
# AUC on testing data with catboost: 0.747
# 76: Encoded Method: OneHotEncoder - Oversampler Method: random - AUC on training data with xgboost: 0.985
# AUC on testing data with xgboost: 0.707
# 77: Encoded Method: OneHotEncoder - Oversampler Method: nearmiss - AUC on training data with logistic_regression: 0.934
# AUC on testing data with logistic_regression: 0.524
# 78: Encoded Method: OneHotEncoder - Oversampler Method: nearmiss - AUC on training data with decision_tree: 0.956
# AUC on testing data with decision_tree: 0.507
# 79: Encoded Method: OneHotEncoder - Oversampler Method: nearmiss - AUC on training data with random_forest: 0.956
# AUC on testing data with random_forest: 0.566
# 80: Encoded Method: OneHotEncoder - Oversampler Method: nearmiss - AUC on training data with gradient_boosting: 0.952
# AUC on testing data with gradient_boosting: 0.516
# 81: Encoded Method: OneHotEncoder - Oversampler Method: nearmiss - AUC on training data with svm: 0.940
# AUC on testing data with svm: 0.540
# 82: Encoded Method: OneHotEncoder - Oversampler Method: nearmiss - AUC on training data with knn: 0.921
# AUC on testing data with knn: 0.539
# 83: Encoded Method: OneHotEncoder - Oversampler Method: nearmiss - AUC on training data with naive_bayes: 0.930
# AUC on testing data with naive_bayes: 0.438
# 84: Encoded Method: OneHotEncoder - Oversampler Method: nearmiss - AUC on training data with mlp: 0.954
# AUC on testing data with mlp: 0.488
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 300, number of negative: 300
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005161 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 44
# [LightGBM] [Info] Number of data points in the train set: 600, number of used features: 22
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# 357: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: tomek - AUC on training data with knn: 0.905
# AUC on testing data with knn: 0.575
# 358: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: tomek - AUC on training data with naive_bayes: 0.736
# AUC on testing data with naive_bayes: 0.745
# 359: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: tomek - AUC on training data with mlp: 0.940
# AUC on testing data with mlp: 0.744
# [LightGBM] [Info] Number of positive: 300, number of negative: 6469
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006927 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 84
# [LightGBM] [Info] Number of data points in the train set: 6769, number of used features: 29
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.044320 -> initscore=-3.070994
# [LightGBM] [Info] Start training from score -3.070994
# 360: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: tomek - AUC on training data with lgbm: 0.948
# AUC on testing data with lgbm: 0.741
# 361: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: tomek - AUC on training data with catboost: 0.932
# AUC on testing data with catboost: 0.766
# 362: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: tomek - AUC on training data with xgboost: 0.960
# AUC on testing data with xgboost: 0.747
# 363: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: centroids - AUC on training data with logistic_regression: 0.927
# AUC on testing data with logistic_regression: 0.732
# 364: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: centroids - AUC on training data with decision_tree: 1.000
# AUC on testing data with decision_tree: 0.548
# 365: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: centroids - AUC on training data with random_forest: 1.000
# AUC on testing data with random_forest: 0.643
# 366: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: centroids - AUC on training data with gradient_boosting: 1.000
# AUC on testing data with gradient_boosting: 0.694
# 367: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: centroids - AUC on training data with svm: 0.969
# AUC on testing data with svm: 0.725
# 368: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: centroids - AUC on training data with knn: 0.903
# AUC on testing data with knn: 0.685
# 369: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: centroids - AUC on training data with naive_bayes: 0.857
# AUC on testing data with naive_bayes: 0.718
# 370: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: centroids - AUC on training data with mlp: 0.978
# AUC on testing data with mlp: 0.721
# [LightGBM] [Info] Number of positive: 300, number of negative: 300
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001606 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 705
# [LightGBM] [Info] Number of data points in the train set: 600, number of used features: 29
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 371: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: centroids - AUC on training data with lgbm: 1.000
# AUC on testing data with lgbm: 0.700
# 372: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: centroids - AUC on training data with catboost: 1.000
# AUC on testing data with catboost: 0.714
# 373: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: centroids - AUC on training data with xgboost: 1.000
# AUC on testing data with xgboost: 0.678
# 374: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: enn - AUC on training data with logistic_regression: 0.831
# AUC on testing data with logistic_regression: 0.773
# 375: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: enn - AUC on training data with decision_tree: 0.996
# AUC on testing data with decision_tree: 0.566
# 376: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: enn - AUC on training data with random_forest: 0.993
# AUC on testing data with random_forest: 0.689
# 377: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: enn - AUC on training data with gradient_boosting: 0.863
# AUC on testing data with gradient_boosting: 0.766
# 378: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: enn - AUC on training data with svm: 0.916
# AUC on testing data with svm: 0.666
# 379: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: enn - AUC on training data with knn: 0.924
# AUC on testing data with knn: 0.578
# 380: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: enn - AUC on training data with naive_bayes: 0.754
# AUC on testing data with naive_bayes: 0.742
# 381: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: enn - AUC on training data with mlp: 0.952
# AUC on testing data with mlp: 0.747
# [LightGBM] [Info] Number of positive: 300, number of negative: 5913
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002122 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 84
# [LightGBM] [Info] Number of data points in the train set: 6213, number of used features: 29
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.048286 -> initscore=-2.981126
# [LightGBM] [Info] Start training from score -2.981126
# 382: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: enn - AUC on training data with lgbm: 0.963
# AUC on testing data with lgbm: 0.739
# 383: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: enn - AUC on training data with catboost: 0.947
# AUC on testing data with catboost: 0.755
# 384: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: enn - AUC on training data with xgboost: 0.975
# AUC on testing data with xgboost: 0.731
# 385: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: allknn - AUC on training data with logistic_regression: 0.828
# AUC on testing data with logistic_regression: 0.773
# 386: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: allknn - AUC on training data with decision_tree: 0.994
# AUC on testing data with decision_tree: 0.573
# 387: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: allknn - AUC on training data with random_forest: 0.991
# AUC on testing data with random_forest: 0.692
# 388: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: allknn - AUC on training data with gradient_boosting: 0.860
# AUC on testing data with gradient_boosting: 0.770
# 389: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: allknn - AUC on training data with svm: 0.912
# AUC on testing data with svm: 0.689
# 390: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: allknn - AUC on training data with knn: 0.917
# AUC on testing data with knn: 0.583
# 391: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: allknn - AUC on training data with naive_bayes: 0.751
# AUC on testing data with naive_bayes: 0.741
# 392: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: allknn - AUC on training data with mlp: 0.955
# AUC on testing data with mlp: 0.736
# [LightGBM] [Info] Number of positive: 300, number of negative: 6074
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002199 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 84
# [LightGBM] [Info] Number of data points in the train set: 6374, number of used features: 29
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.047066 -> initscore=-3.007990
# [LightGBM] [Info] Start training from score -3.007990
# 393: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: allknn - AUC on training data with lgbm: 0.961
# AUC on testing data with lgbm: 0.736
# 394: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: allknn - AUC on training data with catboost: 0.950
# AUC on testing data with catboost: 0.762
# 395: Encoded Method: BackwardDifferenceEncoder - Oversampler Method: allknn - AUC on training data with xgboost: 0.971
# AUC on testing data with xgboost: 0.739

# %%
import matplotlib.pyplot as plt

# Consolidar todos los resultados en una lista
consolidated_results = []
for encoded_method, oversampler_method, sorted_names, train_aucs, test_aucs in all_results:
    for name, train_auc, test_auc in zip(sorted_names, train_aucs, test_aucs):
        full_model_name = f"{encoded_method} - {oversampler_method} - {name}"
        consolidated_results.append((full_model_name, train_auc, test_auc))

# Ordenar los resultados por test_auc de mayor a menor y seleccionar el top
consolidated_results.sort(key=lambda x: x[2], reverse=False)
top_results = consolidated_results[:15]

# Desempaquetar los resultados del top
top_names, top_train_aucs, top_10_test_aucs = zip(*top_results)

plt.figure(figsize=(14, 9))

# Gráfico de líneas para el top
plt.plot(top_names, top_train_aucs, label='Training AUC', marker='o', color='skyblue')
plt.plot(top_names, top_10_test_aucs, label='Testing AUC', marker='o', color='salmon')

# Añadir los valores a los puntos
for i, txt in enumerate(top_train_aucs):
    plt.annotate(f'{txt:.3f}', (top_names[i], top_train_aucs[i]), textcoords="offset points", xytext=(0,10), ha='center', color='blue')
for i, txt in enumerate(top_10_test_aucs):
    plt.annotate(f'{txt:.3f}', (top_names[i], top_10_test_aucs[i]), textcoords="offset points", xytext=(0,-15), ha='center', color='red')

plt.xlabel('Modelos')
plt.ylabel('AUC')
plt.title('Top of 330 Models by Testing AUC')
plt.xticks(rotation=90, fontsize=9)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Consolidar todos los resultados en una lista
consolidated_results = []
for encoded_method, oversampler_method, sorted_names, train_aucs, test_aucs in all_results:
    for name, train_auc, test_auc in zip(sorted_names, train_aucs, test_aucs):
        full_model_name = f"{encoded_method} - {oversampler_method} - {name}"
        consolidated_results.append((full_model_name, train_auc, test_auc))

# Ordenar los resultados por test_auc de mayor a menor y seleccionar el top
consolidated_results.sort(key=lambda x: x[2], reverse=False)
top_results = consolidated_results[-15:]

# Desempaquetar los resultados del top
top_names, top_train_aucs, top_10_test_aucs = zip(*top_results)

plt.figure(figsize=(14, 9))

# Gráfico de líneas para el top
plt.plot(top_names, top_train_aucs, label='Training AUC', marker='o', color='skyblue')
plt.plot(top_names, top_10_test_aucs, label='Testing AUC', marker='o', color='salmon')

# Añadir los valores a los puntos
for i, txt in enumerate(top_train_aucs):
    plt.annotate(f'{txt:.3f}', (top_names[i], top_train_aucs[i]), textcoords="offset points", xytext=(0,10), ha='center', color='blue')
for i, txt in enumerate(top_10_test_aucs):
    plt.annotate(f'{txt:.3f}', (top_names[i], top_10_test_aucs[i]), textcoords="offset points", xytext=(0,-15), ha='center', color='red')

plt.xlabel('Modelos')
plt.ylabel('AUC')
plt.title('Top of 330 Models by Testing AUC')
plt.xticks(rotation=90, fontsize=9)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
